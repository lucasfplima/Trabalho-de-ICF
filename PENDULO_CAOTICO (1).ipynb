# %% [markdown]
# ![pendulo duplo.webp](data:image/webp;base64,...)

# %%
import numpy as np
import sympy as sp
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import PillowWriter

sp.init_printing()

t,g,m1,m2,L1,L2, = sp.symbols('t,g,m1,m2,L1,L2')

the1, the2 = sp.symbols(r'\theta_1, \theta_2')

the1 = sp.Function(the1)(t)
the2 = sp.Function(the2)(t)

# %%
##derivadas primeiras e segundas

dthe1 = sp.diff(the1, t)
dthe2 = sp.diff(the2, t)
d2the1 = sp.diff(dthe1, t)
d2the2 = sp.diff(dthe2, t)

# %%
dthe1
# Out:
# d
# ──(\theta₁(t))
# dt

# %%
dthe2
# Out:
# d
# ──(\theta₂(t))
# dt

# %%
d2the1
# Out:
#   2
#  d
# ───(\theta₁(t))
#   2
# dt

# %%
d2the2
# Out:
#   2
#  d
# ───(\theta₂(t))
#   2
# dt

# %%
##definir as posiçoes das massas x1,y1,x2,y2

x1 = L1*sp.sin(the1)
y1 = -L1*sp.cos(the1)
x2 = L1*sp.sin(the1)+L2*sp.sin(the2)
y2 = -L1*sp.cos(the1)-L2*sp.cos(the2)

# %%
##obter a lagrangeana a partir da energia cinetica e pot gravitacional

# energia cinética

K1 = 1/2 * m1 * (sp.diff(x1, t)**2 + sp.diff(y1, t)**2) # k= 1/2 mv**2 , dx/dt= v,  diff= soma das duas velocidades (x)(y)
K2 = 1/2 * m2 * (sp.diff(x2, t)**2 + sp.diff(y2, t)**2)
K = K1+K2

# energia potencial gravitacional

Pg1 = m1*g*y1
Pg2 = m2*g*y2
PG = Pg1 + Pg2

# lagrangeana

L = K - PG

L
# Out:
#
#
# L₁⋅g⋅m₁⋅cos(\theta₁(t)) - g⋅m₂⋅(-L₁⋅cos(\theta₁(t)) - L₂⋅cos(\theta₂(t))) + 0.
#
#
#      ⎛                                     2
#      ⎜  2    2             ⎛d             ⎞      2    2             ⎛d
# 5⋅m₁⋅⎜L₁ ⋅sin (\theta₁(t))⋅⎜──(\theta₁(t))⎟  + L₁ ⋅cos (\theta₁(t))⋅⎜──(\theta
#      ⎝                     ⎝dt            ⎠                         ⎝dt
#
#       2⎞          ⎛
#      ⎞ ⎟          ⎜⎛                   d                                   d
# ₁(t))⎟ ⎟ + 0.5⋅m₂⋅⎜⎜L₁⋅sin(\theta₁(t))⋅──(\theta₁(t)) + L₂⋅sin(\theta₂(t))⋅──(
#      ⎠ ⎠          ⎝⎝                   dt                                  dt
#
#             2
#            ⎞    ⎛                   d                                   d
# \theta₂(t))⎟  + ⎜L₁⋅cos(\theta₁(t))⋅──(\theta₁(t)) + L₂⋅cos(\theta₂(t))⋅──(\th
#            ⎠    ⎝                   dt                                  dt
#
#          2⎞
#         ⎞ ⎟
# eta₂(t))⎟ ⎟
#         ⎠ ⎠

# %% [markdown]
# Equaçao de lagrange
# ![image.png](data:image/png;base64,...)

# %%
#obtendo as equaçoes de lagrange
EL1 = sp.diff(L, the1) - sp.diff(sp.diff(L, dthe1), t)
EL2 = sp.diff(L, the2) - sp.diff(sp.diff(L, dthe2), t)

# %%
EL1
# Out:
#                                                             ⎛
#                                                             ⎜    2    2
# -L₁⋅g⋅m₁⋅sin(\theta₁(t)) - L₁⋅g⋅m₂⋅sin(\theta₁(t)) - 0.5⋅m₁⋅⎜2⋅L₁ ⋅sin (\theta
#                                                             ⎜
#                                                             ⎝
#
#         2                                        2            ⎞
#        d                    2    2              d             ⎟          ⎛
# ₁(t))⋅───(\theta₁(t)) + 2⋅L₁ ⋅cos (\theta₁(t))⋅───(\theta₁(t))⎟ + 0.5⋅m₂⋅⎜2⋅L₁
#         2                                        2            ⎟          ⎝
#       dt                                       dt             ⎠
#
#
#  ⎛                   d                                   d             ⎞
# ⋅⎜L₁⋅sin(\theta₁(t))⋅──(\theta₁(t)) + L₂⋅sin(\theta₂(t))⋅──(\theta₂(t))⎟⋅cos(\
#  ⎝                   dt                                  dt            ⎠
#
#
#
#            d                     ⎛                   d
# theta₁(t))⋅──(\theta₁(t)) - 2⋅L₁⋅⎜L₁⋅cos(\theta₁(t))⋅──(\theta₁(t)) + L₂⋅cos(\
#            dt                    ⎝                   dt
#
#
#                                                                     ⎛
#            d             ⎞                 d             ⎞          ⎜     ⎛
# theta₂(t))⋅──(\theta₂(t))⎟⋅sin(\theta₁(t))⋅──(\theta₁(t))⎟ - 0.5⋅m₂⋅⎜2⋅L₁⋅⎜L₁⋅
#            dt            ⎠                 dt            ⎠          ⎜     ⎝
#                                                                     ⎝
#
#
#                 d                                   d             ⎞
# sin(\theta₁(t))⋅──(\theta₁(t)) + L₂⋅sin(\theta₂(t))⋅──(\theta₂(t))⎟⋅cos(\theta
#                 dt                                  dt            ⎠
#
#
#
#       d                     ⎛                   d
# ₁(t))⋅──(\theta₁(t)) - 2⋅L₁⋅⎜L₁⋅cos(\theta₁(t))⋅──(\theta₁(t)) + L₂⋅cos(\theta
#       dt                    ⎝                   dt
#
#
#                                                             ⎛
#       d             ⎞                 d                     ⎜
# ₂(t))⋅──(\theta₂(t))⎟⋅sin(\theta₁(t))⋅──(\theta₁(t)) + 2⋅L₁⋅⎜- L₁⋅sin(\theta₁(
#       dt            ⎠                 dt                    ⎜
#                                                             ⎝
#
#                     2                        2
#     ⎛d             ⎞                        d
# t))⋅⎜──(\theta₁(t))⎟  + L₁⋅cos(\theta₁(t))⋅───(\theta₁(t)) - L₂⋅sin(\theta₂(t)
#     ⎝dt            ⎠                         2
#                                            dt
#
#                   2                        2            ⎞
#   ⎛d             ⎞                        d             ⎟
# )⋅⎜──(\theta₂(t))⎟  + L₂⋅cos(\theta₂(t))⋅───(\theta₂(t))⎟⋅cos(\theta₁(t)) + 2⋅
#   ⎝dt            ⎠                         2            ⎟
#                                          dt             ⎠
#
#    ⎛                     2                                                  2
#    ⎜                    d                                   ⎛d             ⎞
# L₁⋅⎜L₁⋅sin(\theta₁(t))⋅───(\theta₁(t)) + L₁⋅cos(\theta₁(t))⋅⎜──(\theta₁(t))⎟
#    ⎜                     2                                  ⎝dt            ⎠
#    ⎝                   dt
#
#                        2                                                  2⎞
#                       d                                   ⎛d             ⎞ ⎟
# + L₂⋅sin(\theta₂(t))⋅───(\theta₂(t)) + L₂⋅cos(\theta₂(t))⋅⎜──(\theta₂(t))⎟ ⎟⋅s
#                        2                                  ⎝dt            ⎠ ⎟
#                      dt                                                    ⎠
#
#               ⎞
#               ⎟
# in(\theta₁(t))⎟
#               ⎟
#               ⎠

# %%
EL2
# Out:
#
#                                   ⎛     ⎛                   d
# -L₂⋅g⋅m₂⋅sin(\theta₂(t)) + 0.5⋅m₂⋅⎜2⋅L₂⋅⎜L₁⋅sin(\theta₁(t))⋅──(\theta₁(t)) + L
#                                   ⎝     ⎝                   dt
#
#
#
#                   d             ⎞                 d                     ⎛
# ₂⋅sin(\theta₂(t))⋅──(\theta₂(t))⎟⋅cos(\theta₂(t))⋅──(\theta₂(t)) - 2⋅L₂⋅⎜L₁⋅co
#                   dt            ⎠                 dt                    ⎝
#
#
#
#               d                                   d             ⎞
# s(\theta₁(t))⋅──(\theta₁(t)) + L₂⋅cos(\theta₂(t))⋅──(\theta₂(t))⎟⋅sin(\theta₂(
#               dt                                  dt            ⎠
#
#
#                              ⎛
#     d             ⎞          ⎜     ⎛                   d
# t))⋅──(\theta₂(t))⎟ - 0.5⋅m₂⋅⎜2⋅L₂⋅⎜L₁⋅sin(\theta₁(t))⋅──(\theta₁(t)) + L₂⋅sin
#     dt            ⎠          ⎜     ⎝                   dt
#                              ⎝
#
#
#              d             ⎞                 d                     ⎛
# (\theta₂(t))⋅──(\theta₂(t))⎟⋅cos(\theta₂(t))⋅──(\theta₂(t)) - 2⋅L₂⋅⎜L₁⋅cos(\th
#              dt            ⎠                 dt                    ⎝
#
#
#
#          d                                   d             ⎞                 d
# eta₁(t))⋅──(\theta₁(t)) + L₂⋅cos(\theta₂(t))⋅──(\theta₂(t))⎟⋅sin(\theta₂(t))⋅─
#          dt                                  dt            ⎠                 d
#
#
#                      ⎛                                     2
#                      ⎜                     ⎛d             ⎞
# ─(\theta₂(t)) + 2⋅L₂⋅⎜- L₁⋅sin(\theta₁(t))⋅⎜──(\theta₁(t))⎟  + L₁⋅cos(\theta₁(
# t                    ⎜                     ⎝dt            ⎠
#                      ⎝
#
#       2                                                  2
#      d                                   ⎛d             ⎞
# t))⋅───(\theta₁(t)) - L₂⋅sin(\theta₂(t))⋅⎜──(\theta₂(t))⎟  + L₂⋅cos(\theta₂(t)
#       2                                  ⎝dt            ⎠
#     dt
#
#     2            ⎞                        ⎛                     2
#    d             ⎟                        ⎜                    d
# )⋅───(\theta₂(t))⎟⋅cos(\theta₂(t)) + 2⋅L₂⋅⎜L₁⋅sin(\theta₁(t))⋅───(\theta₁(t))
#     2            ⎟                        ⎜                     2
#   dt             ⎠                        ⎝                   dt
#
#                                      2                        2
#                      ⎛d             ⎞                        d
# + L₁⋅cos(\theta₁(t))⋅⎜──(\theta₁(t))⎟  + L₂⋅sin(\theta₂(t))⋅───(\theta₂(t)) +
#                      ⎝dt            ⎠                         2
#                                                             dt
#
#                                    2⎞                ⎞
#                    ⎛d             ⎞ ⎟                ⎟
# L₂⋅cos(\theta₂(t))⋅⎜──(\theta₂(t))⎟ ⎟⋅sin(\theta₂(t))⎟
#                    ⎝dt            ⎠ ⎟                ⎟
#                                     ⎠                ⎠

# %%
sol1 = sp.solve([EL1], (d2the1))
sol2 = sp.solve([EL2], (d2the2))

# %%
sol1
# Out:
# ⎧
# ⎪
# ⎪                                         L₂⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t)
# ⎪  2
# ⎨ d
# ⎪───(\theta₁(t)): - ──────────────────────────────────────────────────────────
# ⎪  2                         2                        2
# ⎪dt                 L₁⋅m₁⋅sin (\theta₁(t)) + L₁⋅m₁⋅cos (\theta₁(t)) + L₁⋅m₂⋅si
# ⎩
#
#     2
#    d
# )⋅───(\theta₂(t))
#     2                                                          L₂⋅m₂⋅sin(\thet
#   dt
# ─────────────────────────────────────── - ────────────────────────────────────
#  2                        2                        2                        2
# n (\theta₁(t)) + L₁⋅m₂⋅cos (\theta₁(t))   L₁⋅m₁⋅sin (\theta₁(t)) + L₁⋅m₁⋅cos (
#
#
#
#                                        2
#                        ⎛d             ⎞
# a₁(t))⋅cos(\theta₂(t))⋅⎜──(\theta₂(t))⎟
#                        ⎝dt            ⎠
# ───────────────────────────────────────────────────────────── + ──────────────
#                        2                        2                        2
# \theta₁(t)) + L₁⋅m₂⋅sin (\theta₁(t)) + L₁⋅m₂⋅cos (\theta₁(t))   L₁⋅m₁⋅sin (\th
#
#
#
#                                                              2
#                                              ⎛d             ⎞
#        L₂⋅m₂⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅⎜──(\theta₂(t))⎟
#                                              ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                     2                        2                        2
# eta₁(t)) + L₁⋅m₁⋅cos (\theta₁(t)) + L₁⋅m₂⋅sin (\theta₁(t)) + L₁⋅m₂⋅cos (\theta
#
#
#                                                                       2
#                                                                      d
#                               L₂⋅m₂⋅cos(\theta₁(t))⋅cos(\theta₂(t))⋅───(\theta
#                                                                       2
#                                                                     dt
# ───── - ──────────────────────────────────────────────────────────────────────
#                  2                        2                        2
# ₁(t))   L₁⋅m₁⋅sin (\theta₁(t)) + L₁⋅m₁⋅cos (\theta₁(t)) + L₁⋅m₂⋅sin (\theta₁(t
#
#
#
#
# ₂(t))
#
#                                                                      g⋅m₁⋅sin(
# ─────────────────────────── - ────────────────────────────────────────────────
#               2                        2                        2
# )) + L₁⋅m₂⋅cos (\theta₁(t))   L₁⋅m₁⋅sin (\theta₁(t)) + L₁⋅m₁⋅cos (\theta₁(t))
#
#
#
#
#
#
# \theta₁(t))
# ───────────────────────────────────────────────── - ──────────────────────────
#            2                        2                        2
# + L₁⋅m₂⋅sin (\theta₁(t)) + L₁⋅m₂⋅cos (\theta₁(t))   L₁⋅m₁⋅sin (\theta₁(t)) + L
#
#
#                                                                        ⎫
#                                                                        ⎪
#                                                                        ⎪
#                                                                        ⎪
#              g⋅m₂⋅sin(\theta₁(t))                                      ⎬
# ───────────────────────────────────────────────────────────────────────⎪
#         2                        2                        2            ⎪
# ₁⋅m₁⋅cos (\theta₁(t)) + L₁⋅m₂⋅sin (\theta₁(t)) + L₁⋅m₂⋅cos (\theta₁(t))⎪
#                                                                        ⎭

# %%
sol2
# Out:
# ⎧                                                        2
# ⎪                                                       d
# ⎪                   L₁⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅───(\theta₁(t))
# ⎪  2                                                     2               L₁⋅si
# ⎨ d                                                    dt
# ⎪───(\theta₂(t)): - ────────────────────────────────────────────────── + ─────
# ⎪  2                          2                     2
# ⎪dt                     L₂⋅sin (\theta₂(t)) + L₂⋅cos (\theta₂(t))
# ⎩
#
#
#                                               2
#                               ⎛d             ⎞
# n(\theta₁(t))⋅cos(\theta₂(t))⋅⎜──(\theta₁(t))⎟    L₁⋅sin(\theta₂(t))⋅cos(\thet
#                               ⎝dt            ⎠
# ─────────────────────────────────────────────── - ────────────────────────────
#       2                     2                                2
# L₂⋅sin (\theta₂(t)) + L₂⋅cos (\theta₂(t))              L₂⋅sin (\theta₂(t)) + L
#
#
#                                                                 2
#                        2                                       d
#        ⎛d             ⎞    L₁⋅cos(\theta₁(t))⋅cos(\theta₂(t))⋅───(\theta₁(t))
# a₁(t))⋅⎜──(\theta₁(t))⎟                                         2
#        ⎝dt            ⎠                                       dt
# ──────────────────────── - ──────────────────────────────────────────────────
#      2                               2                     2
# ₂⋅cos (\theta₂(t))             L₂⋅sin (\theta₂(t)) + L₂⋅cos (\theta₂(t))
#
#
#                                            ⎫
#                                            ⎪
#                                            ⎪
#                                            ⎪
#               g⋅sin(\theta₂(t))            ⎬
# - ─────────────────────────────────────────⎪
#         2                     2            ⎪
#   L₂⋅sin (\theta₂(t)) + L₂⋅cos (\theta₂(t))⎪
#                                            ⎭

# %%
#Resolver as equaçoes igual a 0

sol = sp.solve([EL1, EL2], (d2the1, d2the2))
sol
# Out:
# ⎧
# ⎪
# ⎪  2
# ⎨ d
# ⎪───(\theta₁(t)): - ──────────────────────────────────────────────────────────
# ⎪  2                         2                2                        2
# ⎩dt                 L₁⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₁⋅m₁⋅sin (\thet
#
#
#
#                                                                      L₁⋅m₂⋅sin
#
# ──────────────────────────────────────────────────────────────────────────────
#           2                        2                2                        2
# a₁(t))⋅cos (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₁⋅m₁⋅cos
#
#                                                               2
# 2                                             ⎛d             ⎞
#  (\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₂(t))⋅⎜──(\theta₁(t))⎟
#                                               ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                 2                        2                2
# (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# L₁⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₁⋅m₂⋅
#
#
#
#
#
# ───────────────────────────────── + ──────────────────────────────────────────
#    2                2                        2                2
# sin (\theta₂(t))⋅cos (\theta₁(t))   L₁⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) +
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#          2                2                        2                2
# L₁⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(
#
#
#                                 2                             ⎛d             ⎞
#        L₁⋅m₂⋅sin(\theta₁(t))⋅sin (\theta₂(t))⋅cos(\theta₁(t))⋅⎜──(\theta₁(t))⎟
#                                                               ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                2                2                        2                2
# t)) + L₁⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₂⋅sin (\theta₁(t))⋅cos (\t
#
# 2
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# heta₂(t)) - 2.0⋅L₁⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\the
#
#
#
#
#
# ───────────────────────────────────────────────── - ──────────────────────────
#                    2                2                        2
# ta₂(t)) + L₁⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₁⋅m₁⋅sin (\theta₁(t))⋅sin
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# 2                        2                2                        2
#  (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₂(t
#
#
#                                                                 2
#                        L₁⋅m₂⋅sin(\theta₁(t))⋅cos(\theta₁(t))⋅cos (\theta₂(t))⋅
#
# ──────────────────────────────────────────────────────────────────────────────
#       2                        2                2                        2
# ))⋅cos (\theta₁(t)) + L₁⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₂⋅sin (\th
#
#                 2
# ⎛d             ⎞
# ⎜──(\theta₁(t))⎟
# ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#             2
# eta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₁⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\the
#
#
#
#
#
# ───────────────────────────────────────────────────────────────── + ──────────
#                                    2                2                        2
# ta₁(t))⋅cos(\theta₂(t)) + L₁⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₁⋅m₁⋅sin
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                 2                        2                2
# (\theta₁(t))⋅sin (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m
#
#
#                                                                 2
#                                        L₁⋅m₂⋅sin(\theta₂(t))⋅cos (\theta₁(t))⋅
#
# ──────────────────────────────────────────────────────────────────────────────
#      2                2                        2                2
# ₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₁⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t))
#
#                                 2
#                 ⎛d             ⎞
# cos(\theta₂(t))⋅⎜──(\theta₁(t))⎟
#                 ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#            2                2
# + L₁⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₁⋅m₂⋅sin(\theta₁(t))⋅sin(\the
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                    2                2
# ta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₁⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(
#
#
#
#
#
# ─── - ────────────────────────────────────────────────────────────────────────
#                2                2                        2                2
# t))   L₁⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₁(t))⋅cos (\t
#
#
#
#                                                        L₂⋅m₂⋅sin(\theta₁(t))⋅s
#
# ──────────────────────────────────────────────────────────────────────────────
#                      2                2                        2
# heta₂(t)) + L₁⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₁⋅m₁⋅cos (\theta₁(t))⋅c
#
#                                                 2
#   2                             ⎛d             ⎞
# in (\theta₂(t))⋅cos(\theta₂(t))⋅⎜──(\theta₂(t))⎟
#                                 ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#   2                        2                2
# os (\theta₂(t)) + L₁⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₁⋅m₂⋅sin(\the
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                    2
# ta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₁⋅m₂⋅sin (\theta₂(t
#
#
#
#
#
# ─────────────────── - ────────────────────────────────────────────────────────
#       2                        2                2                        2
# ))⋅cos (\theta₁(t))   L₁⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₁⋅m₁⋅sin (\th
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#             2                        2                2
# eta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₁⋅m₁⋅co
#
#                                                         2
#                           3             ⎛d             ⎞
#  L₂⋅m₂⋅sin(\theta₁(t))⋅cos (\theta₂(t))⋅⎜──(\theta₂(t))⎟
#                                         ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#  2                2                        2                2
# s (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# 0⋅L₁⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₁⋅m
#
#
#
#
#
# ─────────────────────────────────── + ────────────────────────────────────────
#      2                2                        2                2
# ₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₁⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t))
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#            2                2                        2                2
# + L₁⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₂(t))⋅cos (\theta
#
#                                                                         2
#                           3                             ⎛d             ⎞
#                  L₂⋅m₂⋅sin (\theta₂(t))⋅cos(\theta₁(t))⋅⎜──(\theta₂(t))⎟
#                                                         ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                  2                2                        2                2
# ₁(t)) + L₁⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₂⋅sin (\theta₁(t))⋅cos (
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# \theta₂(t)) - 2.0⋅L₁⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\t
#
#
#
#
#
# ─────────────────────────────────────────────────── + ────────────────────────
#                      2                2                        2
# heta₂(t)) + L₁⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₁⋅m₁⋅sin (\theta₁(t))⋅s
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#   2                        2                2                        2
# in (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₂
#
#
#                                                                   2
#                          L₂⋅m₂⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos (\theta₂(t)
#
# ──────────────────────────────────────────────────────────────────────────────
#         2                        2                2                        2
# (t))⋅cos (\theta₁(t)) + L₁⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₂⋅sin (\
#
#                   2
#   ⎛d             ⎞
# )⋅⎜──(\theta₂(t))⎟
#   ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#               2
# theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₁⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\t
#
#
#
#
#
# ─────────────────────────────────────────────────────────────────── - ────────
#                                      2                2
# heta₁(t))⋅cos(\theta₂(t)) + L₁⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₁⋅m₁⋅si
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#  2                2                        2                2
# n (\theta₁(t))⋅sin (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₁
#
#
#
#
#                                                           g⋅m₁⋅sin(\theta₁(t))
# ──────────────────────────────────────────────────────────────────────────────
#        2                2                        2                2
# ⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₁⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)
#
#
#
#     2
# ⋅sin (\theta₂(t))
# ──────────────────────────────────────────────────────────────────────────────
#              2                2
# ) + L₁⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₁⋅m₂⋅sin(\theta₁(t))⋅sin(\t
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                      2                2
# heta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₁⋅m₂⋅sin (\theta₂(t))⋅cos (\theta
#
#
#
#
#
# ───── - ──────────────────────────────────────────────────────────────────────
#                  2                2                        2                2
# ₁(t))   L₁⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₁(t))⋅cos (
#
#
#
#
#                                                                           g⋅m₁
# ──────────────────────────────────────────────────────────────────────────────
#                        2                2                        2
# \theta₂(t)) + L₁⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₁⋅m₁⋅cos (\theta₁(t))
#
#
#
#                     2
# ⋅sin(\theta₁(t))⋅cos (\theta₂(t))
# ──────────────────────────────────────────────────────────────────────────────
#     2                        2                2
# ⋅cos (\theta₂(t)) + L₁⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₁⋅m₂⋅sin(\t
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                      2
# heta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₁⋅m₂⋅sin (\theta₂
#
#
#
#
#
# ───────────────────── - ──────────────────────────────────────────────────────
#         2                        2                2                        2
# (t))⋅cos (\theta₁(t))   L₁⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₁⋅m₁⋅sin (\
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#               2                        2                2
# theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₁⋅m₁⋅
#
#
#
#                                     2
#             g⋅m₂⋅sin(\theta₁(t))⋅cos (\theta₂(t))
# ──────────────────────────────────────────────────────────────────────────────
#    2                2                        2                2
# cos (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) -
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# 2.0⋅L₁⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₁
#
#
#
#
#
# ───────────────────────────────────── + ──────────────────────────────────────
#        2                2                        2                2
# ⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₁⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#              2                2                        2                2
# ) + L₁⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₁⋅sin (\theta₂(t))⋅cos (\the
#
#
#
#
#                      g⋅m₂⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t))
# ──────────────────────────────────────────────────────────────────────────────
#                    2                2                        2
# ta₁(t)) + L₁⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₁⋅m₂⋅sin (\theta₁(t))⋅cos
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# 2
#  (\theta₂(t)) - 2.0⋅L₁⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(
#
#
#
#                                                          2
#                                                         d
# ─────────────────────────────────────────────────────, ───(\theta₂(t)): ──────
#                        2                2                2
# \theta₂(t)) + L₁⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))  dt               L₂⋅m₁⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#    2                2                        2                2
# sin (\theta₁(t))⋅sin (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) +
#
#
#                                                             3
#                                                    L₁⋅m₁⋅sin (\theta₁(t))⋅cos(
#
# ──────────────────────────────────────────────────────────────────────────────
#          2                2                        2                2
# L₂⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₂⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(
#
#                             2
#             ⎛d             ⎞
# \theta₂(t))⋅⎜──(\theta₁(t))⎟
#             ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                2                2
# t)) + L₂⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₂⋅m₂⋅sin(\theta₁(t))⋅sin(
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                        2                2
# \theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₂⋅m₂⋅sin (\theta₂(t))⋅cos (\the
#
#
#
#
#
# ─────── - ────────────────────────────────────────────────────────────────────
#                    2                2                        2
# ta₁(t))   L₂⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₁(t))⋅cos
#
#
#                                                                     2
#                                                            L₁⋅m₁⋅sin (\theta₁(
#
# ──────────────────────────────────────────────────────────────────────────────
# 2                        2                2                        2
#  (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₂⋅m₁⋅cos (\theta₁(t
#
#                                                     2
#                                     ⎛d             ⎞
# t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅⎜──(\theta₁(t))⎟
#                                     ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#       2                        2                2
# ))⋅cos (\theta₂(t)) + L₂⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₂⋅m₂⋅sin(
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                        2
# \theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₂⋅m₂⋅sin (\thet
#
#
#
#
#
# ─────────────────────── + ────────────────────────────────────────────────────
#           2                        2                2                        2
# a₂(t))⋅cos (\theta₁(t))   L₂⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₂⋅m₁⋅sin
#
#
#
#                                                                            L₁⋅
#
# ──────────────────────────────────────────────────────────────────────────────
#                 2                        2                2
# (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₂⋅m
#
#                                                                     2
#                       2                             ⎛d             ⎞
# m₁⋅sin(\theta₁(t))⋅cos (\theta₁(t))⋅cos(\theta₂(t))⋅⎜──(\theta₁(t))⎟
#                                                     ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#      2                2                        2                2
# ₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t))
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# - 2.0⋅L₂⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) +
#
#
#
#
#
# ─────────────────────────────────────── - ────────────────────────────────────
#          2                2                        2                2
# L₂⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₂⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                2                2                        2                2
# t)) + L₂⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₂(t))⋅cos (\t
#
#                                                                             2
#                                               3             ⎛d             ⎞
#                      L₁⋅m₁⋅sin(\theta₂(t))⋅cos (\theta₁(t))⋅⎜──(\theta₁(t))⎟
#                                                             ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                      2                2                        2
# heta₁(t)) + L₂⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₂⋅sin (\theta₁(t))⋅c
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#   2
# os (\theta₂(t)) - 2.0⋅L₂⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅co
#
#
#
#
#
# ─────────────────────────────────────────────────────── + ────────────────────
#                          2                2                        2
# s(\theta₂(t)) + L₂⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₂⋅m₁⋅sin (\theta₁(t
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#       2                        2                2                        2
# ))⋅sin (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₁⋅sin (\th
#
#
#                                               3                             ⎛d
#                                      L₁⋅m₂⋅sin (\theta₁(t))⋅cos(\theta₂(t))⋅⎜─
#                                                                             ⎝d
# ──────────────────────────────────────────────────────────────────────────────
#             2                        2                2
# eta₂(t))⋅cos (\theta₁(t)) + L₂⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₂⋅si
#
#               2
#              ⎞
# ─(\theta₁(t))⎟
# t            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#  2                2
# n (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₂⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅co
#
#
#
#
#
# ─────────────────────────────────────────────────────────────────────── - ────
#                                          2                2
# s(\theta₁(t))⋅cos(\theta₂(t)) + L₂⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₂⋅m
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#      2                2                        2                2
# ₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t))
#
#
#                                                       2
#                                              L₁⋅m₂⋅sin (\theta₁(t))⋅sin(\theta
#
# ──────────────────────────────────────────────────────────────────────────────
#            2                2                        2                2
# + L₂⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₂⋅m₁⋅cos (\theta₁(t))⋅cos (\theta
#
#                                       2
#                       ⎛d             ⎞
# ₂(t))⋅cos(\theta₁(t))⋅⎜──(\theta₁(t))⎟
#                       ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                  2                2
# ₂(t)) + L₂⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₂⋅m₂⋅sin(\theta₁(t))⋅si
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                          2                2
# n(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₂⋅m₂⋅sin (\theta₂(t))⋅cos (\t
#
#
#
#
#
# ───────── + ──────────────────────────────────────────────────────────────────
#                      2                2                        2
# heta₁(t))   L₂⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₁(t))⋅c
#
#
#
#                                                              L₁⋅m₂⋅sin(\theta₁
#
# ──────────────────────────────────────────────────────────────────────────────
#   2                        2                2                        2
# os (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₂⋅m₁⋅cos (\theta₁
#
#                                                       2
#         2                             ⎛d             ⎞
# (t))⋅cos (\theta₁(t))⋅cos(\theta₂(t))⋅⎜──(\theta₁(t))⎟
#                                       ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#         2                        2                2
# (t))⋅cos (\theta₂(t)) + L₂⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₂⋅m₂⋅si
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                          2
# n(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₂⋅m₂⋅sin (\th
#
#
#
#
#
# ───────────────────────── - ──────────────────────────────────────────────────
#             2                        2                2
# eta₂(t))⋅cos (\theta₁(t))   L₂⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₂⋅m₁⋅si
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#  2                2                        2                2
# n (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₂
#
#                                                               2
#                                 3             ⎛d             ⎞
#        L₁⋅m₂⋅sin(\theta₂(t))⋅cos (\theta₁(t))⋅⎜──(\theta₁(t))⎟
#                                               ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#        2                2                        2                2
# ⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# ) - 2.0⋅L₂⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t))
#
#
#
#
#
# ───────────────────────────────────────── + ──────────────────────────────────
#            2                2                        2                2
# + L₂⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₂⋅m₁⋅sin (\theta₁(t))⋅sin (\theta
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                  2                2                        2                2
# ₂(t)) + L₂⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₂(t))⋅cos (
#
#
#                         2                                             ⎛d
#                L₂⋅m₂⋅sin (\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₂(t))⋅⎜──(\the
#                                                                       ⎝dt
# ...
#
# ──────────────────────────────────────────────────────────────────────────────
#         2                        2                2                        2
# (t))⋅sin (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₁⋅sin (\
#
#
#                                                         2
#                                L₂⋅m₂⋅sin(\theta₁(t))⋅sin (\theta₂(t))⋅cos(\the
#
# ──────────────────────────────────────────────────────────────────────────────
#               2                        2                2
# theta₂(t))⋅cos (\theta₁(t)) + L₂⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₂⋅
#
#                         2
#         ⎛d             ⎞
# ta₁(t))⋅⎜──(\theta₂(t))⎟
#         ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#    2                2
# sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₂⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅
#
#
#
#
#
# ───────────────────────────────────────────────────────────────────────── + ──
#                                            2                2
# cos(\theta₁(t))⋅cos(\theta₂(t)) + L₂⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₂
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#        2                2                        2                2
# ⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)
#
#
#
#                                                L₂⋅m₂⋅sin(\theta₁(t))⋅cos(\thet
#
# ──────────────────────────────────────────────────────────────────────────────
#              2                2                        2                2
# ) + L₂⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₂⋅m₁⋅cos (\theta₁(t))⋅cos (\the
#
#                                         2
#           2             ⎛d             ⎞
# a₁(t))⋅cos (\theta₂(t))⋅⎜──(\theta₂(t))⎟
#                         ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                    2                2
# ta₂(t)) + L₂⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₂⋅m₂⋅sin(\theta₁(t))⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                            2                2
# sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₂⋅m₂⋅sin (\theta₂(t))⋅cos (
#
#
#
#
#
# ─────────── - ────────────────────────────────────────────────────────────────
#                        2                2                        2
# \theta₁(t))   L₂⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₁(t))
#
#
#
#                                                                L₂⋅m₂⋅sin(\thet
#
# ──────────────────────────────────────────────────────────────────────────────
#     2                        2                2                        2
# ⋅cos (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₂⋅m₁⋅cos (\thet
#
#                                                         2
#           2                             ⎛d             ⎞
# a₂(t))⋅cos (\theta₁(t))⋅cos(\theta₂(t))⋅⎜──(\theta₂(t))⎟
#                                         ⎝dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#           2                        2                2
# a₁(t))⋅cos (\theta₂(t)) + L₂⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₂⋅m₂⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                            2
# sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₂⋅m₂⋅sin (\
#
#
#
#
#
# ─────────────────────────── + ────────────────────────────────────────────────
#               2                        2                2
# theta₂(t))⋅cos (\theta₁(t))   L₂⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₂⋅m₁⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#    2                2                        2                2
# sin (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) +
#
#
#
#
#            g⋅m₁⋅sin(\theta₁(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t))
# ──────────────────────────────────────────────────────────────────────────────
#          2                2                        2                2
# L₂⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# t)) - 2.0⋅L₂⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)
#
#
#
#
#
# ─────────────────────────────────────────── - ────────────────────────────────
#              2                2                        2                2
# ) + L₂⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₂⋅m₁⋅sin (\theta₁(t))⋅sin (\the
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                    2                2                        2
# ta₂(t)) + L₂⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₂(t))⋅cos
#
#
#
#                                                           2
#                                   g⋅m₁⋅sin(\theta₂(t))⋅cos (\theta₁(t))
# ──────────────────────────────────────────────────────────────────────────────
# 2                        2                2                        2
#  (\theta₁(t)) + L₂⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₂⋅sin (\theta₁(t
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#       2
# ))⋅cos (\theta₂(t)) - 2.0⋅L₂⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t))⋅cos(\theta₁(t)
#
#
#
#
#
# ─────────────────────────────────────────────────────────── + ────────────────
#                              2                2                        2
# )⋅cos(\theta₂(t)) + L₂⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))   L₂⋅m₁⋅sin (\thet
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#           2                        2                2                        2
# a₁(t))⋅sin (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m₁⋅sin
#
#
#
#
#                                            g⋅m₂⋅sin(\theta₁(t))⋅cos(\theta₁(t)
# ──────────────────────────────────────────────────────────────────────────────
#                 2                        2                2
# (\theta₂(t))⋅cos (\theta₁(t)) + L₂⋅m₁⋅cos (\theta₁(t))⋅cos (\theta₂(t)) + L₂⋅m
#
#
#
#
# )⋅cos(\theta₂(t))
# ──────────────────────────────────────────────────────────────────────────────
#      2                2
# ₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₂⋅m₂⋅sin(\theta₁(t))⋅sin(\theta₂(t)
#
#
#
#
#
# ─────────────────────────────────────────────────────────────────────────── -
#                                              2                2
# )⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₂⋅m₂⋅sin (\theta₂(t))⋅cos (\theta₁(t))
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#          2                2                        2                2
# L₂⋅m₁⋅sin (\theta₁(t))⋅sin (\theta₂(t)) + L₂⋅m₁⋅sin (\theta₁(t))⋅cos (\theta₂(
#
#
#
#
#                                                                   g⋅m₂⋅sin(\th
# ──────────────────────────────────────────────────────────────────────────────
#                2                2                        2                2
# t)) + L₂⋅m₁⋅sin (\theta₂(t))⋅cos (\theta₁(t)) + L₂⋅m₁⋅cos (\theta₁(t))⋅cos (\t
#
#
#
#             2
# eta₂(t))⋅cos (\theta₁(t))
# ──────────────────────────────────────────────────────────────────────────────
#                      2                2
# heta₂(t)) + L₂⋅m₂⋅sin (\theta₁(t))⋅cos (\theta₂(t)) - 2.0⋅L₂⋅m₂⋅sin(\theta₁(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                              2
# )⋅sin(\theta₂(t))⋅cos(\theta₁(t))⋅cos(\theta₂(t)) + L₂⋅m₂⋅sin (\theta₂(t))⋅cos
#
#              ⎫
#              ⎪
#              ⎪
#              ⎬
# ─────────────⎪
# 2            ⎪
#  (\theta₁(t))⎭

# %%
## transformando 2 EDO's de segunda ordem  um sistema de 4 EDO's primeira ordem

# %% [markdown]
# $\frac{d^2\theta_1}{dt^2}$
#
# $\frac{d^2\theta_2}{dt^2}$
#
# transformado em
#
# dz$_1$/dt
#
# dΘ$_1$/dt= z1
#
# dz$_2$/dt
#
# dΘ$_ 2$/dt= z1

# %%
##Coverter simbolos por numeros por lambdificaçao

dz1dt_f = sp.lambdify((t,g,m1,m2,L1,L2,the1,the2,dthe1,dthe2), sol[d2the1])
dz2dt_f = sp.lambdify((t,g,m1,m2,L1,L2,the1,the2,dthe1,dthe2), sol[d2the2])
dthe1dt_f = sp.lambdify(dthe1, dthe1)
dthe2dt_f = sp.lambdify(dthe2, dthe2)

# %%
###função para as condições iniciais do probelma
def iniciais(I, t, g, m1, m2, L1, L2):
    the1, z1, the2, z2 = I
    return [
        dthe1dt_f(z1),
        dz1dt_f(t, g, m1, m2, L1, L2, the1, the2, z1, z2),
        dthe2dt_f(z2),
        dz2dt_f(t, g, m1, m2, L1, L2, the1, the2, z1, z2),
    ]

# %%
t = np.linspace(0, 60, 1001)
g = 9.81
m1= 1000
m2=1001
L1 = 1
L2 = 1

# %%
matriz = odeint(iniciais, y0=[8, 2, 5, -2], t=t, args=(g,m1,m2,L1,L2))
matriz
# Out:
# array([[ 8.        ,  2.        ,  5.        , -2.        ],
#        [ 8.10242138,  1.42174866,  4.88002204, -1.99670678],
#        [ 8.17203679,  0.91190927,  4.76182982, -1.92656801],
#        ...,
#        [ 7.56050602,  3.3522109 , -2.10813528,  6.33181868],
#        [ 7.75319001,  3.02334766, -1.72392648,  6.46219999],
#        [ 7.91571943,  2.31711207, -1.33725349,  6.36431718]])

# %%
matriz.T  #### como a matriz ficou thetha1, dtheta1, theta2, dthetha2 nas colunas, precisamos transpor pra conseguir pegar mais facilmente os resultados de cada coordenada e suas derivadas
# Out:
# array([[ 8.        ,  8.10242138,  8.17203679, ...,  7.56050602,
#          7.75319001,  7.91571943],
#        [ 2.        ,  1.42174866,  0.91190927, ...,  3.3522109 ,
#          3.02334766,  2.31711207],
#        [ 5.        ,  4.88002204,  4.76182982, ..., -2.10813528,
#         -1.72392648, -1.33725349],
#        [-2.        , -1.99670678, -1.92656801, ...,  6.33181868,
#          6.46219999,  6.36431718]])

# %%
the1 = matriz.T[0]
the2 = matriz.T[2]

# %%
#### gráfico theta 2 x tempo
plt.plot(t, the2)

# %%
#### gráfico theta 1 x tempo
plt.plot(t, the1)

# %%
def coordenadas(t, the1, the2, L1, L2):
    return (L1*np.sin(the1),
            -L1*np.cos(the1),
            L1*np.sin(the1) + L2*np.sin(the2),
            -L1*np.cos(the1) - L2*np.cos(the2))

x1, y1, x2, y2 = coordenadas(t, matriz.T[0], matriz.T[2], L1, L2)

# %%
def gif(i):
    ln1.set_data([0, x1[i], x2[i]], [0, y1[i], y2[i]])

fig, ax = plt.subplots(1,1, figsize=(8,8))
ln1, = plt.plot([], [], 'ro--', lw=3, markersize=8)
ax.set_ylim(-5,5)
ax.set_xlim(-5,5)
ani = animation.FuncAnimation(fig, gif, frames=1000, interval=50)
ani.save('pendulo.gif',writer='pillow',fps=25)
